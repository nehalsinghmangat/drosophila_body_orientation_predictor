# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
from CleanData import *
from MergeData import *
from AugmentData import *
from CorrectHeading import *
from PlotData import *

# %%
# import pre-cleaned data 
trajec_df = pd.read_hdf("../ExperimentalData/60cms/flight_trajectories_3d_HCS_odor_horizon_matched.h5")
body_df = pd.read_hdf("../ExperimentalData/60cms/body_orientations_HCS_odor_horizon_matched.h5")
key_table = pd.read_hdf("../ExperimentalData/60cms/body_trajec_matches.h5")

# %%
trajec_df = correct_for_wind(trajec_df)
trajec_df = remove_irrelevant_trajectory_data(trajec_df)
synced_trajectory = sync_time(trajec_df)
body_df = remove_irrelevant_body_data(body_df)
synced_body = sync_time(body_df)

# %%
fly_body_and_trajectory = join_body_and_trajectory(synced_body,synced_trajectory,key_table,"20130404_181148_237")

# %%
fly_body_and_trajectory
# Out:
#            trajec_objid  timestamp  position_x  position_y  velocity_x  \
# 0   20130404_181148_237      49.94    0.173368   -0.006566    0.029990
# 1   20130404_181148_237      49.95    0.173676   -0.004388    0.033894
# 2   20130404_181148_237      49.96    0.174095   -0.001919    0.052414
# 3   20130404_181148_237      49.97    0.174773    0.000742    0.085551
# 4   20130404_181148_237      49.98    0.175855    0.003497    0.133305
# 5   20130404_181148_237      49.99    0.177466    0.006240    0.189196
# 6   20130404_181148_237      50.00    0.179625    0.008847    0.240985
# 7   20130404_181148_237      50.01    0.182253    0.011202    0.282916
# 8   20130404_181148_237      50.02    0.185241    0.013209    0.312028
# 9   20130404_181148_237      50.03    0.188434    0.014829    0.323338
# 10  20130404_181148_237      50.04    0.191639    0.016094    0.314168
# 11  20130404_181148_237      50.05    0.194653    0.017105    0.285714
# ...

# %%
augmented_test_fly_data = augment_df(fly_body_and_trajectory)

# %%
augmented_test_fly_data
# Out:
#            trajec_objid  timestamp  position_x  position_y  velocity_x  \
# 0   20130404_181148_237       0.00    0.173368   -0.006566    0.029990
# 1   20130404_181148_237       0.01    0.173676   -0.004388    0.033894
# 2   20130404_181148_237       0.02    0.174095   -0.001919    0.052414
# 3   20130404_181148_237       0.03    0.174773    0.000742    0.085551
# 4   20130404_181148_237       0.04    0.175855    0.003497    0.133305
# 5   20130404_181148_237       0.05    0.177466    0.006240    0.189196
# 6   20130404_181148_237       0.06    0.179625    0.008847    0.240985
# 7   20130404_181148_237       0.07    0.182253    0.011202    0.282916
# 8   20130404_181148_237       0.08    0.185241    0.013209    0.312028
# 9   20130404_181148_237       0.09    0.188434    0.014829    0.323338
# 10  20130404_181148_237       0.10    0.191639    0.016094    0.314168
# 11  20130404_181148_237       0.11    0.194653    0.017105    0.285714
# ...

# %%
plot_trajectory(augmented_test_fly_data)

# %%
corrected_fly_and_body = correct_heading_jumps(augmented_test_fly_data)

# %%
plot_trajectory(corrected_fly_and_body)

# %%
all_flies_body_and_trajectory = join_all_body_and_trajectory(synced_body, synced_trajectory, key_table)

# %%
all_flies_body_and_trajectory[0]
# Out:
#            trajec_objid  timestamp  position_x  position_y  velocity_x  \
# 0  20130418_190232_4763      18.36    0.163545    0.015919   -0.182362
# 1  20130418_190232_4763      18.37    0.161751    0.018762   -0.176452
# 2  20130418_190232_4763      18.38    0.160017    0.021261   -0.170149
# 3  20130418_190232_4763      18.39    0.158344    0.023459   -0.165034
# 4  20130418_190232_4763      18.40    0.156710    0.025408   -0.161958
# 5  20130418_190232_4763      18.41    0.155101    0.027159   -0.159921
# 6  20130418_190232_4763      18.42    0.153509    0.028750   -0.158668
# 7  20130418_190232_4763      18.43    0.151925    0.030216   -0.158282
#
#    velocity_y  airvelocity_x  airvelocity_y  eccentricity  ellipse_short_angle
# 0    0.302807      -0.782362       0.302807      0.715929            -1.382689
# 1    0.266447      -0.776452       0.266447      0.750000            -1.301117
# 2    0.234044      -0.770149       0.234044      0.600000            -1.610290
# ...

# %%
augmented_all_flies_body_and_trajectory = [augment_df(fly_body_and_trajectory) for fly_body_and_trajectory in all_flies_body_and_trajectory]

# %%
augmented_all_flies_body_and_trajectory[0]
# Out:
#            trajec_objid  timestamp  position_x  position_y  velocity_x  \
# 0  20130418_190232_4763       0.00    0.163545    0.015919   -0.182362
# 1  20130418_190232_4763       0.01    0.161751    0.018762   -0.176452
# 2  20130418_190232_4763       0.02    0.160017    0.021261   -0.170149
# 3  20130418_190232_4763       0.03    0.158344    0.023459   -0.165034
# 4  20130418_190232_4763       0.04    0.156710    0.025408   -0.161958
# 5  20130418_190232_4763       0.05    0.155101    0.027159   -0.159921
# 6  20130418_190232_4763       0.06    0.153509    0.028750   -0.158668
# 7  20130418_190232_4763       0.07    0.151925    0.030216   -0.158282
#
#    velocity_y  airvelocity_x  airvelocity_y  eccentricity  \
# 0    0.302807      -0.782362       0.302807      0.715929
# 1    0.266447      -0.776452       0.266447      0.750000
# 2    0.234044      -0.770149       0.234044      0.600000
# 3    0.206490      -0.765034       0.206490      0.634986
# ...

# %%
corrected_all_flies_body_and_trajectory = [correct_heading_jumps(augmented_fly_body_and_trajectory) for augmented_fly_body_and_trajectory in augmented_all_flies_body_and_trajectory]

# %%
len(corrected_all_flies_body_and_trajectory)
# Out:
# 1386

# %%
shitty_all_flies_body_and_trajectory = []
for index,fly_body_and_trajectory in enumerate(corrected_all_flies_body_and_trajectory):
    if max(great_circle_distance_between_corrected_heading_angle(fly_body_and_trajectory)) > np.pi / 2:
        shitty_all_flies_body_and_trajectory.append(corrected_all_flies_body_and_trajectory.pop(index))

# %%
len(corrected_all_flies_body_and_trajectory)
# Out:
# 901

# %%
# for fly in corrected_all_flies_body_and_trajectory:
#     plot_trajectory(fly)

# %%
# for fly in shitty_all_flies_body_and_trajectory:
#     plot_trajectory(fly)
